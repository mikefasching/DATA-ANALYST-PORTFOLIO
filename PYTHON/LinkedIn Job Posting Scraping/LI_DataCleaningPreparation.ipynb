# %%
import pandas as pd

# %%
data_de_seattle = pd.read_csv('job_data_engineer_Seattle.csv')
data_de_ny = pd.read_csv('job_data_engineer_NYC.csv')
data_de_sf = pd.read_csv('job_data_engineer_sanfrancisco.csv')
data_ds_seattle = pd.read_csv('job_data_scientist_Seattle.csv')
data_ds_ny = pd.read_csv('job_data_scientist_NYC.csv')
data_ds_sf = pd.read_csv('job_data_scientist_sanfrancisco.csv')
data_da_seattle = pd.read_csv('job_data_analyst_Seattle.csv')
data_da_ny = pd.read_csv('job_data_analyst_NYC.csv')
data_da_sf = pd.read_csv('job_data_analyst_sanfrancisco.csv')

data = pd.concat([data_de_seattle, data_de_ny, data_de_sf, data_ds_seattle, data_ds_ny, data_ds_sf, data_da_seattle, data_da_ny, data_da_sf], ignore_index=True)
# Check for duplicates based on URLs
data.drop_duplicates(subset=['role', 'location', 'company'], inplace=True)
print(len(data))
# Out:
# 2470

# %%
# Create new Column Job Type -> either Data Analyst, Engineer, Business INtelligence, Data Scientist, Machine LEarning, software development
#Assigning the job type to each row in the dataset
import re

patterns = {
    'DE': r'Data\s*Engineer',
    'DA': r'Data\s+.*?\s*(Analy(?:st|sis|tics|tic))\b(?:,)?',
    'BI': r'Business\s*Intelligence|BI',
    'DS': r'Data\s*Scientist|Data\s*Science',
    'SD': r'Software\s*(?:Development|Engineer)',
    'ML': r'Machine\s*Learning|ML',
    'RE': r'Researcher\s'
}

def assign_type(role):
    for job_type, pattern in patterns.items():
        if pd.notnull(role) and pd.notnull(pattern) and re.search(pattern, role, flags=re.IGNORECASE):
            return job_type
    return 'other'

# Apply the function to create the 'type' column
data['type'] = data['role'].apply(assign_type)

# %%
# Create new column to see Professional level (Director, Staff, Intern, Principal/Manager)
#Assigning the professional level to each row in the dataset
data['level'] = data['role'].apply(lambda x: 'DI' if 'Director' in x else
                                      ('ST' if 'Staff' in x else
                                      ('IN' if 'Intern' in x or 'Internship' in x else
                                      ('PR' if 'Principal' in x or 'Manager' in x else'normal'))))

# %%
# Create new column to see work schedule (on-site or hybrid)
#Assigning the professional level to each row in the dataset
data['schedule'] = data.apply(lambda row: 'on-site' if 'on-site' in str(row['location']).lower() or 'on-site' in str(row['description']).lower()
                              else ('hybrid' if 'hybrid' in str(row['location']).lower() or 'hybrid' in str(row['description']).lower()
                                    else ('remote' if 'remote' in str(row['location']).lower() or 'remote' in str(row['description']).lower()
                                          else 'NaN')), axis=1)

# %%
# extract salary range
# Extract salary range using regex and convert to strings
# Extract salary range using regex
salary_range = data['description'].str.extract(r'\$([\d,]+)[^\d\w]*([\d,]+)')

# Assign 'min' and 'max' columns
data['min_salary'] = salary_range[0]
data['max_salary'] = salary_range[1]

# Fill NaN values with 'NaN'
data['min_salary'].fillna('NaN', inplace=True)
data['max_salary'].fillna('NaN', inplace=True)

# %%
data.tail(50)
# Out:
#                                                     url  \
# 2880  https://www.linkedin.com/jobs/view/3886477578/...
# 2881  https://www.linkedin.com/jobs/view/3808324386/...
# 2882  https://www.linkedin.com/jobs/view/3808319594/...
# 2883  https://www.linkedin.com/jobs/view/3853055772/...
# 2884  https://www.linkedin.com/jobs/view/3879609175/...
# 2885  https://www.linkedin.com/jobs/view/3817568279/...
# 2886  https://www.linkedin.com/jobs/view/3895428803/...
# 2888  https://www.linkedin.com/jobs/view/3589429366/...
# 2893  https://www.linkedin.com/jobs/view/3886443473/...
# 2894  https://www.linkedin.com/jobs/view/3893244325/...
# 2895  https://www.linkedin.com/jobs/view/3855647367/...
# 2898  https://www.linkedin.com/jobs/view/3814505450/...
# 2900  https://www.linkedin.com/jobs/view/3855178619/...
# 2902  https://www.linkedin.com/jobs/view/3893931223/...
# 2903  https://www.linkedin.com/jobs/view/3890896231/...
# 2904  https://www.linkedin.com/jobs/view/3837397375/...
# 2906  https://www.linkedin.com/jobs/view/3880131576/...
# 2907  https://www.linkedin.com/jobs/view/3859662068/...
# 2912  https://www.linkedin.com/jobs/view/3882258840/...
# 2913  https://www.linkedin.com/jobs/view/3888245705/...
# 2914  https://www.linkedin.com/jobs/view/3893416677/...
# 2926  https://www.linkedin.com/jobs/view/3856264113/...
# 2927  https://www.linkedin.com/jobs/view/3784870891/...
# 2932  https://www.linkedin.com/jobs/view/3877430012/...
# 2933  https://www.linkedin.com/jobs/view/3881102276/...
# 2934  https://www.linkedin.com/jobs/view/3808316870/...
# 2935  https://www.linkedin.com/jobs/view/3861755041/...
# 2936  https://www.linkedin.com/jobs/view/3886728394/...
# 2940  https://www.linkedin.com/jobs/view/3894612890/...
# 2942  https://www.linkedin.com/jobs/view/3850850554/...
# 2950  https://www.linkedin.com/jobs/view/3885037602/...
# 2952  https://www.linkedin.com/jobs/view/3872026336/...
# 2955  https://www.linkedin.com/jobs/view/3897008633/...
# 2964  https://www.linkedin.com/jobs/view/3871589603/...
# 2969  https://www.linkedin.com/jobs/view/3871629687/...
# 2972  https://www.linkedin.com/jobs/view/3896984267/...
# 2974  https://www.linkedin.com/jobs/view/3816707929/...
# 2979  https://www.linkedin.com/jobs/view/3897359569/...
# 2982  https://www.linkedin.com/jobs/view/3881966017/...
# 2984  https://www.linkedin.com/jobs/view/3859478703/...
# 2989  https://www.linkedin.com/jobs/view/3788642888/...
# 2990  https://www.linkedin.com/jobs/view/3881939863/...
# 2995  https://www.linkedin.com/jobs/view/3777225813/...
# 3003  https://www.linkedin.com/jobs/view/3854738372/...
# 3015  https://www.linkedin.com/jobs/view/3897073155/...
# 3031  https://www.linkedin.com/jobs/view/3845656519/...
# 3036  https://www.linkedin.com/jobs/view/3893322149/...
# 3037  https://www.linkedin.com/jobs/view/3830558462/...
# 3038  https://www.linkedin.com/jobs/view/3895436803/...
# 3039  https://www.linkedin.com/jobs/view/3863873275/...
#
#                            company                             location  \
# 2880               The Judge Group          San Francisco, CA (On-site)
# 2881                DataAnnotation                 Oakland, CA (Remote)
# 2882                DataAnnotation             Santa Clara, CA (Remote)
# 2883                         Adobe                         San Jose, CA
# 2884            Turn/River Capital                    San Francisco, CA
# 2885                        TikTok                         San Jose, CA
# 2886                       Walmart                        San Bruno, CA
# 2888                        TikTok                         San Jose, CA
# 2893           Stanford University               Stanford, CA (On-site)
# 2894        U.S. Air Force Reserve     San Francisco Bay Area (On-site)
# 2895                        TikTok                    Mountain View, CA
# 2898                        TikTok                    Mountain View, CA
# 2900                        TikTok                         San Jose, CA
# 2902                      Rippling           San Francisco, CA (Hybrid)
# 2903                    MatchPoint      San Francisco Bay Area (Remote)
# 2904                       Notable                        San Mateo, CA
# 2906                    Kforce Inc  San Jose, California, United States
# 2907                         Adobe                         San Jose, CA
# 2912                     BlackRock           San Francisco, CA (Hybrid)
# 2913                         Chime                    San Francisco, CA
# 2914                        McAfee                San Jose, CA (Remote)
# 2926                      Doximity      San Francisco Bay Area (Remote)
# 2927                      Doximity      San Francisco Bay Area (Remote)
# 2932                    Terrascope   California, United States (Remote)
# 2933                Coherent Corp.                Fremont, CA (On-site)
# 2934                DataAnnotation           Mountain View, CA (Remote)
# 2935     San Francisco Health Plan           San Francisco, CA (Hybrid)
# 2936                         Tesla                Fremont, CA (On-site)
# 2940                       Genesys   California, United States (Remote)
# 2942            Franklin Templeton   California, United States (Remote)
# 2950               Zolon Tech Inc.               Cupertino, CA (Remote)
# 2952               Cardinal Health   California, United States (Remote)
# 2955                     BCforward              Palo Alto, CA (On-site)
# 2964                       ThredUp                          Oakland, CA
# 2969                        Airbnb           San Francisco, CA (Remote)
# 2972                     Snowflake                        San Mateo, CA
# 2974                         WayUp                    San Francisco, CA
# 2979          Central Garden & Pet           Walnut Creek, CA (On-site)
# 2982                 Russell Tobin              Sunnyvale, CA (On-site)
# 2984                  Akraya, Inc.             Santa Clara, CA (Remote)
# 2989                          Lyft    San Francisco County, CA (Hybrid)
# 2990                      Deloitte                San Jose, CA (Hybrid)
# 2995                       Promise                 Oakland, CA (Hybrid)
# 3003                        Deputy           San Francisco, CA (Hybrid)
# 3015  Western Governors University          San Francisco, CA (On-site)
# 3031                          FICO              San Rafael, CA (Remote)
# 3036                    Braintrust      San Francisco Bay Area (Remote)
# 3037                        Stripe          San Francisco, CA (On-site)
# 3038                        Square           San Francisco, CA (Remote)
# 3039             US Tech Solutions           San Francisco, CA (Remote)
#
#                                                    role  \
# 2880  Data analyst with marketing analytics exp. (10...
# 2881                                       Data Analyst
# 2882                                       Data Analyst
# 2883            2024 SAMI Intern – People Data Analyst
# 2884                   Revenue Operations, Data Analyst
# 2885  Operations Data Analyst - Trust and Safety - S...
# 2886  Senior, Data Analyst - Last Mile Transportatio...
# 2888                        TikTok Shop - Data Analyst
# 2893                                 Biostatistician 1
# 2894                                       Data Analyst
# 2895             Data Analyst, Risk Data Mining - USDS
# 2898            Data Analyst, Payment Analytics - USDS
# 2900             HR Operations Data Analyst - San Jose
# 2902         Senior Compensation & People Data Analyst
# 2903                                 Lead Data Analyst
# 2904                                       Data Analyst
# 2906                           Data Governance Analyst
# 2907              Senior Business Intelligence Analyst
# 2912            Associate or Analyst, Data Engineering
# 2913          Senior Data Analyst, Lifecycle Marketing
# 2914               Data Analyst, Pricing Team - Remote
# 2926                     Business Intelligence Analyst
# 2927                                      Data Analyst
# 2932                                Carbon Data Analyst
# 2933                  Reliability Data Analysis Intern
# 2934                                       Data Analyst
# 2935                              Insights Data Analyst
# 2936  Internship, Data Analyst, Supply Chain (Fall 2...
# 2940          CS North America Insights Senior Analyst
# 2942                    Senior Investment Data Analyst
# 2950                                      Data Analyst
# 2952                         Data Analyst - Nationwide
# 2955                        Data Annotation Analyst II
# 2964                             Data Analyst, Revenue
# 2969       Lead Analyst, Advanced Analytics (contract)
# 2972               Senior Business Intelligence Analyst
# 2974  Public Notice for Direct Hire (Data Modernizat...
# 2979                   Data & Analytics Analyst Intern
# 2982                                      Data Analyst
# 2984                             Data Analyst: 24-00724
# 2989              Data Analyst, Strategy & Diagnostics
# 2990         People Analytics Visier Senior Consultant
# 2995                                   Insights Analyst
# 3003                                      Data Analyst
# 3015                               Senior Data Analyst
# 3031                             Analytic Consultant I
# 3036                 Cyber Risk/ Data Analyst - US Only
# 3037                      Masters, Data Analyst Intern
# 3038               Senior Data Analyst, Square Banking
# 3039           Fraud/Risk Data Analyst (SQL, Snowflake
#
#                                             description  applicants  \
# 2880  \n            \n              About the job\n ...       100.0
# 2881  \n            \n              About the job\n ...       100.0
# 2882  \n            \n              About the job\n ...       100.0
# 2883  \n            \n              About the job\n ...       100.0
# 2884  \n            \n              About the job\n ...       100.0
# 2885  \n            \n              About the job\n ...       100.0
# 2886  \n            \n              About the job\n ...       100.0
# 2888  \n            \n              About the job\n ...       100.0
# 2893  \n            \n              About the job\n ...        59.0
# 2894  \n            \n              About the job\n ...       100.0
# 2895  \n            \n              About the job\n ...       100.0
# 2898  \n            \n              About the job\n ...       100.0
# 2900  \n            \n              About the job\n ...       100.0
# 2902  \n            \n              About the job\n ...        64.0
# 2903  \n            \n              About the job\n ...       100.0
# 2904  \n            \n              About the job\n ...       100.0
# 2906  \n            \n              About the job\n ...        77.0
# 2907  \n            \n              About the job\n ...       100.0
# 2912  \n            \n              About the job\n ...       100.0
# 2913  \n            \n              About the job\n ...       100.0
# 2914  \n            \n              About the job\n ...       100.0
# 2926  \n            \n              About the job\n ...       100.0
# 2927  \n            \n              About the job\n ...       100.0
# 2932  \n            \n              About the job\n ...       100.0
# 2933  \n            \n              About the job\n ...       100.0
# 2934  \n            \n              About the job\n ...       100.0
# 2935  \n            \n              About the job\n ...       100.0
# 2936  \n            \n              About the job\n ...       100.0
# 2940  \n            \n              About the job\n ...        31.0
# 2942  \n            \n              About the job\n ...       100.0
# 2950  \n            \n              About the job\n ...       100.0
# 2952  \n            \n              About the job\n ...       100.0
# 2955  \n            \n              About the job\n ...        94.0
# 2964  \n            \n              About the job\n ...       100.0
# 2969  \n            \n              About the job\n ...       100.0
# 2972  \n            \n              About the job\n ...       100.0
# 2974  \n            \n              About the job\n ...         2.0
# 2979  \n            \n              About the job\n ...       100.0
# 2982  \n            \n              About the job\n ...       100.0
# 2984  \n            \n              About the job\n ...       100.0
# 2989  \n            \n              About the job\n ...       100.0
# 2990  \n            \n              About the job\n ...        12.0
# 2995  \n            \n              About the job\n ...       100.0
# 3003  \n            \n              About the job\n ...       100.0
# 3015  \n            \n              About the job\n ...        21.0
# 3031  \n            \n              About the job\n ...       100.0
# 3036  \n            \n              About the job\n ...        65.0
# 3037  \n            \n              About the job\n ...       100.0
# 3038  \n            \n              About the job\n ...       100.0
# 3039  \n            \n              About the job\n ...       100.0
#
#       post_days   type   level schedule min_salary max_salary
# 2880        5.0     DA  normal  on-site         50         00
# 2881        3.0     DA  normal   remote          4          0
# 2882        3.0     DA  normal   remote          4          0
# 2883       30.0     DA      IN      NaN         25         00
# 2884        5.0     DA  normal   hybrid        NaN        NaN
# 2885       30.0     DA  normal      NaN      98400     232222
# 2886        3.0     DA  normal      NaN    104,000         00
# 2888       30.0     DA  normal      NaN     132187     312000
# 2893        5.0     BI  normal  on-site      91,00          0
# 2894        3.0     DA  normal  on-site      10,00          0
# 2895       30.0     DA  normal   hybrid      86555     177777
# 2898       30.0     DA  normal   hybrid     106400     177777
# 2900       30.0     DA  normal      NaN      72000     116000
# 2902        3.0     DA  normal   hybrid          1          2
# 2903        3.0     DA  normal   remote        NaN        NaN
# 2904       30.0     DA  normal      NaN         10          5
# 2906        7.0     DA  normal      NaN         40         70
# 2907       28.0     BI  normal      NaN     88,600    206,300
# 2912        7.0     DE  normal   hybrid    132,500    157,500
# 2913        6.0     DA  normal      NaN     148,50          0
# 2914        4.0     DA  normal   remote     79,310         00
# 2926        6.0     BI  normal   remote          4          3
# 2927       30.0     DA  normal   remote    110,000    150,000
# 2932        7.0     DA  normal   remote        NaN        NaN
# 2933        7.0     DA      IN  on-site        NaN        NaN
# 2934        3.0     DA  normal   remote          4          0
# 2935       21.0     DA  normal   hybrid     82,000     91,000
# 2936        6.0     DA      IN  on-site         16         35
# 2940        2.0  other  normal   remote     66,050         00
# 2942       30.0     DA  normal   hybrid     145,00          0
# 2950        7.0     DA  normal   remote        NaN        NaN
# 2952       14.0     DA  normal   remote     78,500    112,100
# 2955        2.0     DA  normal  on-site        NaN        NaN
# 2964       14.0     DA  normal   hybrid     130,00          0
# 2969       14.0  other  normal   remote         72         86
# 2972        2.0     BI  normal      NaN    121,000    163,800
# 2974       60.0  other  normal   remote        NaN        NaN
# 2979        2.0     DA      IN  on-site        NaN        NaN
# 2982        7.0     DA  normal  on-site          4          5
# 2984       14.0     DA  normal   remote         25         14
# 2989       28.0     DA  normal   hybrid    100,000    115,000
# 2990        7.0  other  normal   hybrid     119,02          5
# 2995       30.0  other  normal   hybrid          5          0
# 3003       30.0     DA  normal   hybrid    118,000    126,480
# 3015        2.0     DA  normal  on-site     70,100         00
# 3031       30.0  other  normal   remote     100,00          0
# 3036        4.0     DA  normal   remote        NaN        NaN
# 3037       60.0     DA      IN  on-site    137,800    137,800
# 3038        3.0     DA  normal   remote     135,20          0
# 3039       21.0     DA  normal   remote        NaN        NaN

# %%
import re
import pandas as pd

operational_skills = pd.read_csv('operational.csv')
packages_skills = pd.read_csv('packages.csv')
tech_skills = pd.read_csv('technologies.csv')


# Convert skills lists to lowercase
operational_skills['Skill'] = operational_skills['Skill'].str.lower()
packages_skills['Skill'] = packages_skills['Skill'].str.lower()
tech_skills['Skill'] = tech_skills['Skill'].str.lower()

# Combine all skill sets into a single set
all_skills_set = set(operational_skills['Skill']).union(set(packages_skills['Skill']), set(tech_skills['Skill']))

# Convert the combined set back to a list without duplicates
all_skills_list = list(all_skills_set)

# Create a new DataFrame to store the results
result_data = pd.DataFrame()
data['description'] = data['description'].str.lower()

# Apply the regular expression pattern to each description in the 'description' column
for skill in all_skills_list:
    if len(skill) == 1:
        pattern = r"\b{}\b".format(re.escape(skill))
    else:
        pattern = re.compile(re.escape(skill), flags=re.IGNORECASE)
    result_data[skill] = data['description'].apply(lambda row: 'yes' if re.findall(pattern, str(row)) else 'no')

# Concatenate the original data DataFrame with the result_data DataFrame
data = pd.concat([data, result_data], axis=1)

# %%
data.head(15)
# Out:
#                                                   url  \
# 0   https://www.linkedin.com/jobs/view/3830178037/...
# 1   https://www.linkedin.com/jobs/view/3871458999/...
# 2   https://www.linkedin.com/jobs/view/3877281608/...
# 3   https://www.linkedin.com/jobs/view/3788649375/...
# 4   https://www.linkedin.com/jobs/view/3834018551/...
# 5   https://www.linkedin.com/jobs/view/3885905325/...
# 6   https://www.linkedin.com/jobs/view/3813589257/...
# 7   https://www.linkedin.com/jobs/view/3891072619/...
# 8   https://www.linkedin.com/jobs/view/3851220242/...
# 9   https://www.linkedin.com/jobs/view/3877281376/...
# 10  https://www.linkedin.com/jobs/view/3872003310/...
# 11  https://www.linkedin.com/jobs/view/3877274974/...
# 12  https://www.linkedin.com/jobs/view/3829551165/...
# 13  https://www.linkedin.com/jobs/view/3843622508/...
# 14  https://www.linkedin.com/jobs/view/3879390207/...
#
#                       company                location  \
# 0                      Google   Seattle, WA (On-site)
# 1                       Adobe             Seattle, WA
# 2   Amazon Web Services (AWS)             Seattle, WA
# 3                      Google  Kirkland, WA (On-site)
# 4                      Google   Seattle, WA (On-site)
# 5         Castle Design Build  Kirkland, WA (On-site)
# 6                      Google  Kirkland, WA (On-site)
# 7     Centillion Infotech LLC  Bellevue, WA (On-site)
# 8                       Adobe             Seattle, WA
# 9   Amazon Web Services (AWS)             Seattle, WA
# 10  Tata Consultancy Services  Bellevue, WA (On-site)
# 11  Amazon Web Services (AWS)             Seattle, WA
# 12                     Oracle    Seattle, WA (Hybrid)
# 13                  Qualtrics   Seattle, WA (On-site)
# 14  Amazon Web Services (AWS)            Bellevue, WA
#
#                                                  role  \
# 0   Développeur de solutions terrain III, IA génér...
# 1       Senior ML Training GPU Optimization Engineer
# 2   Sr. Physical Security Engineer, Data Center De...
# 3   Principal Engineer, Query Processing, Spanner,...
# 4   Développeur de solutions terrain II, IA généra...
# 5                                       Data Engineer
# 6   Senior Staff Software Engineer, Machine Learni...
# 7                                    Data Engineer II
# 8   Sr. Full Stack Engineer - Typographic Intellig...
# 9   Sr. Business Intelligence Engineer, Partner In...
# 10                                Data Engineer Lead
# 11  Business Intelligence Engineer, Next Generatio...
# 12  Data Center-Electrical Engineer (build, commis...
# 13         Staff Machine Learning Engineer/Architect
# 14  Business Intelligence Engineer, Data Services ...
#
#                                           description  applicants  post_days  \
# 0   \n            \n              about the job\n ...         1.0       30.0
# 1   \n            \n              about the job\n ...        10.0       14.0
# 2   \n            \n              about the job\n ...         0.0       14.0
# 3   \n            \n              about the job\n ...        69.0       30.0
# 4   \n            \n              about the job\n ...         2.0       30.0
# 5   \n            \n              about the job\n ...       100.0        4.0
# 6   \n            \n              about the job\n ...        29.0       30.0
# 7   \n            \n              about the job\n ...       100.0        4.0
# 8   \n            \n              about the job\n ...        62.0       30.0
# 9   \n            \n              about the job\n ...        15.0       14.0
# 10  \n            \n              about the job\n ...        30.0       14.0
# 11  \n            \n              about the job\n ...        15.0       14.0
# 12  \n            \n              about the job\n ...       100.0       21.0
# 13  \n            \n              about the job\n ...        76.0       30.0
# 14  \n            \n              about the job\n ...        46.0        7.0
#
#      type   level schedule  ... pandas docker julia sass grafana scala  \
# 0   other  normal  on-site  ...     no     no    no   no      no    no
# 1      ML  normal      NaN  ...     no    yes    no   no      no    no
# 2   other  normal      NaN  ...     no     no    no   no      no    no
# 3   other      PR  on-site  ...     no     no    no   no      no    no
# 4   other  normal  on-site  ...     no     no    no   no      no    no
# 5      DE  normal  on-site  ...    yes     no    no   no      no    no
# 6      SD      ST  on-site  ...     no     no    no   no      no    no
# 7      DE  normal  on-site  ...     no     no    no   no      no    no
# 8   other  normal      NaN  ...     no     no    no   no      no   yes
# 9      BI  normal      NaN  ...     no     no    no   no      no    no
# 10     DE  normal  on-site  ...     no     no    no   no      no    no
# 11     BI  normal      NaN  ...     no     no    no   no      no    no
# 12  other  normal  on-site  ...     no     no    no   no      no    no
# 13     ML      ST  on-site  ...     no     no    no   no      no   yes
# 14     DA  normal      NaN  ...     no     no    no   no      no   yes
#
#    redshift    r hive lightgbm
# 0        no   no   no       no
# 1        no   no   no       no
# 2        no   no   no       no
# 3        no   no   no       no
# 4        no   no   no       no
# 5        no   no   no       no
# 6        no   no   no       no
# 7       yes   no   no       no
# 8        no  yes   no       no
# 9        no   no   no       no
# 10       no   no   no       no
# 11       no   no   no       no
# 12       no   no   no       no
# 13       no  yes   no       no
# 14      yes  yes   no       no
#
# [15 rows x 90 columns]

# %%
# Assuming your dataframe is named 'df' and the column is named 'Location'
data['city'] = [location.split(',')[0].strip() if ',' in location else 'remote' for location in data['location']]
data['state'] = [location.split(',')[1].strip() if ',' in location else 'remote' for location in data['location']]
#remove hybrid and remote
data['state'] = data['state'].str.replace('(On-site)', '').str.replace('(Hybrid)', '')
#data[['city', 'state']] = data[['city', 'state']].fillna('remote')

# %%
data.head(50)
# Out:
#                                                   url  \
# 0   https://www.linkedin.com/jobs/view/3830178037/...
# 1   https://www.linkedin.com/jobs/view/3871458999/...
# 2   https://www.linkedin.com/jobs/view/3877281608/...
# 3   https://www.linkedin.com/jobs/view/3788649375/...
# 4   https://www.linkedin.com/jobs/view/3834018551/...
# 5   https://www.linkedin.com/jobs/view/3885905325/...
# 6   https://www.linkedin.com/jobs/view/3813589257/...
# 7   https://www.linkedin.com/jobs/view/3891072619/...
# 8   https://www.linkedin.com/jobs/view/3851220242/...
# 9   https://www.linkedin.com/jobs/view/3877281376/...
# 10  https://www.linkedin.com/jobs/view/3872003310/...
# 11  https://www.linkedin.com/jobs/view/3877274974/...
# 12  https://www.linkedin.com/jobs/view/3829551165/...
# 13  https://www.linkedin.com/jobs/view/3843622508/...
# 14  https://www.linkedin.com/jobs/view/3879390207/...
# 15  https://www.linkedin.com/jobs/view/3868956021/...
# 16  https://www.linkedin.com/jobs/view/3846235636/...
# 17  https://www.linkedin.com/jobs/view/3880443699/...
# 18  https://www.linkedin.com/jobs/view/3836174020/...
# 19  https://www.linkedin.com/jobs/view/3835349699/...
# 20  https://www.linkedin.com/jobs/view/3877287179/...
# 21  https://www.linkedin.com/jobs/view/3869776863/...
# 22  https://www.linkedin.com/jobs/view/3868958063/...
# 23  https://www.linkedin.com/jobs/view/3868952174/...
# 24  https://www.linkedin.com/jobs/view/3865042314/...
# 25  https://www.linkedin.com/jobs/view/3867115638/...
# 26  https://www.linkedin.com/jobs/view/3846998664/...
# 27  https://www.linkedin.com/jobs/view/3861153589/...
# 28  https://www.linkedin.com/jobs/view/3856838669/...
# 29  https://www.linkedin.com/jobs/view/3823073855/...
# 30  https://www.linkedin.com/jobs/view/3877282725/...
# 31  https://www.linkedin.com/jobs/view/3877274090/...
# 32  https://www.linkedin.com/jobs/view/3863973517/...
# 33  https://www.linkedin.com/jobs/view/3863363592/...
# 34  https://www.linkedin.com/jobs/view/3873208033/...
# 35  https://www.linkedin.com/jobs/view/3812929373/...
# 36  https://www.linkedin.com/jobs/view/3891615419/...
# 37  https://www.linkedin.com/jobs/view/3873759174/...
# 38  https://www.linkedin.com/jobs/view/3804673419/...
# 39  https://www.linkedin.com/jobs/view/3882205343/...
# 40  https://www.linkedin.com/jobs/view/3843749064/...
# 41  https://www.linkedin.com/jobs/view/3773738819/...
# 42  https://www.linkedin.com/jobs/view/3880453817/...
# 43  https://www.linkedin.com/jobs/view/3877271203/...
# 44  https://www.linkedin.com/jobs/view/3882999613/...
# 45  https://www.linkedin.com/jobs/view/3863973516/...
# 46  https://www.linkedin.com/jobs/view/3868958147/...
# 47  https://www.linkedin.com/jobs/view/3812923857/...
# 48  https://www.linkedin.com/jobs/view/3868958107/...
# 49  https://www.linkedin.com/jobs/view/3897766871/...
#
#                                   company                location  \
# 0                                  Google   Seattle, WA (On-site)
# 1                                   Adobe             Seattle, WA
# 2               Amazon Web Services (AWS)             Seattle, WA
# 3                                  Google  Kirkland, WA (On-site)
# 4                                  Google   Seattle, WA (On-site)
# 5                     Castle Design Build  Kirkland, WA (On-site)
# 6                                  Google  Kirkland, WA (On-site)
# 7                 Centillion Infotech LLC  Bellevue, WA (On-site)
# 8                                   Adobe             Seattle, WA
# 9               Amazon Web Services (AWS)             Seattle, WA
# 10              Tata Consultancy Services  Bellevue, WA (On-site)
# 11              Amazon Web Services (AWS)             Seattle, WA
# 12                                 Oracle    Seattle, WA (Hybrid)
# 13                              Qualtrics   Seattle, WA (On-site)
# 14              Amazon Web Services (AWS)            Bellevue, WA
# 15                              Microsoft             Redmond, WA
# 16                                  Adobe             Seattle, WA
# 17                    Booz Allen Hamilton    Seattle, WA (Hybrid)
# 18                                  Adobe             Seattle, WA
# 19                                   Rokt    Seattle, WA (Hybrid)
# 20                                 Amazon             Seattle, WA
# 21                              DermaSkan  United States (Remote)
# 22                              Microsoft    Redmond, WA (Hybrid)
# 23                              Microsoft    Redmond, WA (Hybrid)
# 24  Pacific Northwest National Laboratory   Seattle, WA (On-site)
# 25                                 Google    Seattle, WA (Hybrid)
# 26                                 Google   Seattle, WA (On-site)
# 27                                 Google   Seattle, WA (On-site)
# 28                                 Google   Seattle, WA (On-site)
# 29                                  Adobe             Seattle, WA
# 30              Amazon Web Services (AWS)             Seattle, WA
# 31              Amazon Web Services (AWS)             Seattle, WA
# 32                              GeoComply   Seattle, WA (On-site)
# 33                                  Adobe             Seattle, WA
# 34              Tata Consultancy Services    Seattle, WA (Hybrid)
# 35                                   Meta             Redmond, WA
# 36                                  Boomi  United States (Remote)
# 37                              Microsoft    Redmond, WA (Hybrid)
# 38                                Equinix   Seattle, WA (On-site)
# 39                 Warner Bros. Discovery  Bellevue, WA (On-site)
# 40                              Snap Inc.            Bellevue, WA
# 41                               Duolingo   Seattle, WA (On-site)
# 42                                 Amazon             Seattle, WA
# 43                           Amazon Games             Seattle, WA
# 44                                   Meta            Bellevue, WA
# 45                              GeoComply   Seattle, WA (On-site)
# 46                              Microsoft    Redmond, WA (Hybrid)
# 47                                   Meta            Bellevue, WA
# 48                              Microsoft    Redmond, WA (Hybrid)
# 49                           Aretec, Inc.  United States (Remote)
#
#                                                  role  \
# 0   Développeur de solutions terrain III, IA génér...
# 1       Senior ML Training GPU Optimization Engineer
# 2   Sr. Physical Security Engineer, Data Center De...
# 3   Principal Engineer, Query Processing, Spanner,...
# 4   Développeur de solutions terrain II, IA généra...
# 5                                       Data Engineer
# 6   Senior Staff Software Engineer, Machine Learni...
# 7                                    Data Engineer II
# 8   Sr. Full Stack Engineer - Typographic Intellig...
# 9   Sr. Business Intelligence Engineer, Partner In...
# 10                                Data Engineer Lead
# 11  Business Intelligence Engineer, Next Generatio...
# 12  Data Center-Electrical Engineer (build, commis...
# 13         Staff Machine Learning Engineer/Architect
# 14  Business Intelligence Engineer, Data Services ...
# 15  Principal Machine Learning Engineer – Foundati...
# 16          Sr ML Training GPU Optimization Engineer
# 17            Enterprise Reporting Tableau Developer
# 18         Senior Machine Learning Engineer, Firefly
# 19         Staff Machine Learning Engineer - Seattle
# 20                       Data Engineer, Amazon Prime
# 21           Data Scientist/Machine Learning Engineer
# 22               Principal Research Software Engineer
# 23                            Senior Storage Engineer
# 24                   AI Software Engineer 3 – Seattle
# 25  Senior Staff Software Engineer, Machine Learni...
# 26  Staff Software Engineer, Infrastructure, Googl...
# 27  Staff Software Engineer, Generative AI, Chrome...
# 28  Senior Software Engineer, Google Cloud Compute...
# 29                  Senior Machine Learning Engineer
# 30                    Data Engineer, AWS Energy Team
# 31  Software Engineer- AI/ML, AWS Neuron Distribut...
# 32           Business Intelligence Engineer (Seattle)
# 33   Sr. Software Engineer, Adobe Analytics Platform
# 34                                 AWS Data Engineer
# 35                          Data Engineer, Analytics
# 36    Jr. Data Engineer Intern (Summer 2024, Hybrid)
# 37                        Principal Software Engineer
# 38  DoD Military Skillbridge - Data Center Facilit...
# 39  Senior Staff Software Engineer - Machine Learn...
# 40                    Business Intelligence Engineer
# 41                           Client Release Engineer
# 42              Data Engineer I, Intl. Seller Growth
# 43        Data Engineer II - Data & AI, Amazon Games
# 44                                     Data Engineer
# 45                            Data Engineer (Seattle)
# 46  Senior Research Engineer – Generative AI – Mic...
# 47                          Data Engineer, Analytics
# 48                      Research Software Engineer II
# 49                                      Data Engineer
#
#                                           description  applicants  post_days  \
# 0   \n            \n              about the job\n ...         1.0       30.0
# 1   \n            \n              about the job\n ...        10.0       14.0
# 2   \n            \n              about the job\n ...         0.0       14.0
# 3   \n            \n              about the job\n ...        69.0       30.0
# 4   \n            \n              about the job\n ...         2.0       30.0
# 5   \n            \n              about the job\n ...       100.0        4.0
# 6   \n            \n              about the job\n ...        29.0       30.0
# 7   \n            \n              about the job\n ...       100.0        4.0
# 8   \n            \n              about the job\n ...        62.0       30.0
# 9   \n            \n              about the job\n ...        15.0       14.0
# 10  \n            \n              about the job\n ...        30.0       14.0
# 11  \n            \n              about the job\n ...        15.0       14.0
# 12  \n            \n              about the job\n ...       100.0       21.0
# 13  \n            \n              about the job\n ...        76.0       30.0
# 14  \n            \n              about the job\n ...        46.0        7.0
# 15  \n            \n              about the job\n ...        18.0       14.0
# 16  \n            \n              about the job\n ...        17.0       30.0
# 17  \n            \n              about the job\n ...        43.0        7.0
# 18  \n            \n              about the job\n ...        73.0       30.0
# 19  \n            \n              about the job\n ...       100.0       14.0
# 20  \n            \n              about the job\n ...       100.0       14.0
# 21  \n            \n              about the job\n ...       100.0       14.0
# 22  \n            \n              about the job\n ...         8.0       14.0
# 23  \n            \n              about the job\n ...        29.0       14.0
# 24  \n            \n              about the job\n ...        56.0       21.0
# 25  \n            \n              about the job\n ...         4.0       21.0
# 26  \n            \n              about the job\n ...        17.0       30.0
# 27  \n            \n              about the job\n ...        11.0       21.0
# 28  \n            \n              about the job\n ...        52.0       30.0
# 29  \n            \n              about the job\n ...       100.0       21.0
# 30  \n            \n              about the job\n ...       100.0       14.0
# 31  \n            \n              about the job\n ...        13.0       14.0
# 32  \n            \n              about the job\n ...       100.0       21.0
# 33  \n            \n              about the job\n ...       100.0       21.0
# 34  \n            \n              about the job\n ...       100.0       14.0
# 35  \n            \n              about the job\n ...       100.0       21.0
# 36  \n            \n              about the job\n ...       100.0        6.0
# 37  \n            \n              about the job\n ...         5.0       14.0
# 38  \n            \n              about the job\n ...        19.0       28.0
# 39  \n            \n              about the job\n ...        26.0        7.0
# 40  \n            \n              about the job\n ...       100.0       30.0
# 41  \n            \n              about the job\n ...       100.0       30.0
# 42  \n            \n              about the job\n ...       100.0        7.0
# 43  \n            \n              about the job\n ...        56.0       14.0
# 44  \n            \n              about the job\n ...       100.0        7.0
# 45  \n            \n              about the job\n ...       100.0       21.0
# 46  \n            \n              about the job\n ...        25.0       14.0
# 47  \n            \n              about the job\n ...       100.0       21.0
# 48  \n            \n              about the job\n ...        52.0       14.0
# 49  \n            \n              about the job\n ...       100.0        7.0
#
#      type   level schedule  ... julia sass grafana scala redshift    r hive  \
# 0   other  normal  on-site  ...    no   no      no    no       no   no   no
# 1      ML  normal      NaN  ...    no   no      no    no       no   no   no
# 2   other  normal      NaN  ...    no   no      no    no       no   no   no
# 3   other      PR  on-site  ...    no   no      no    no       no   no   no
# 4   other  normal  on-site  ...    no   no      no    no       no   no   no
# 5      DE  normal  on-site  ...    no   no      no    no       no   no   no
# 6      SD      ST  on-site  ...    no   no      no    no       no   no   no
# 7      DE  normal  on-site  ...    no   no      no    no      yes   no   no
# 8   other  normal      NaN  ...    no   no      no   yes       no  yes   no
# 9      BI  normal      NaN  ...    no   no      no    no       no   no   no
# 10     DE  normal  on-site  ...    no   no      no    no       no   no   no
# 11     BI  normal      NaN  ...    no   no      no    no       no   no   no
# 12  other  normal  on-site  ...    no   no      no    no       no   no   no
# 13     ML      ST  on-site  ...    no   no      no   yes       no  yes   no
# 14     DA  normal      NaN  ...    no   no      no   yes      yes  yes   no
# 15     ML      PR      NaN  ...    no   no      no   yes       no   no   no
# 16     ML  normal      NaN  ...    no   no      no    no       no   no   no
# 17  other  normal   hybrid  ...    no   no      no    no       no   no   no
# 18     ML  normal      NaN  ...    no   no      no   yes       no   no   no
# 19     ML      ST   hybrid  ...    no   no      no    no       no   no   no
# 20     DE  normal      NaN  ...    no   no      no   yes      yes   no   no
# 21     DS  normal   remote  ...    no   no      no    no       no   no   no
# 22     SD      PR   hybrid  ...    no   no      no    no       no   no   no
# 23  other  normal   hybrid  ...    no   no      no    no       no   no   no
# 24     SD  normal  on-site  ...    no   no      no   yes      yes   no   no
# 25     SD      ST   hybrid  ...    no   no      no    no       no   no   no
# 26     SD      ST  on-site  ...    no   no      no    no       no   no   no
# 27     SD      ST  on-site  ...    no   no      no    no       no   no   no
# 28     SD  normal  on-site  ...    no   no      no    no       no   no   no
# 29     ML  normal      NaN  ...    no   no      no   yes       no   no   no
# 30     DE  normal      NaN  ...    no   no      no    no      yes   no   no
# 31     SD  normal      NaN  ...    no   no      no    no       no   no   no
# 32     BI  normal  on-site  ...    no   no      no    no      yes   no   no
# 33     SD  normal      NaN  ...    no   no     yes   yes       no   no   no
# 34     DE  normal   hybrid  ...    no   no      no    no       no   no   no
# 35     DE  normal      NaN  ...    no   no      no    no       no   no   no
# 36     DE      IN   remote  ...    no   no      no    no       no   no   no
# 37     SD      PR   hybrid  ...    no   no      no    no       no   no   no
# 38  other  normal  on-site  ...    no   no      no    no       no   no   no
# 39     SD      ST  on-site  ...    no   no      no   yes       no   no   no
# 40     BI  normal      NaN  ...    no   no      no   yes       no  yes   no
# 41  other  normal  on-site  ...    no   no      no    no       no   no   no
# 42     DE  normal      NaN  ...    no   no      no   yes       no   no  yes
# 43     DE  normal      NaN  ...    no   no      no    no      yes   no   no
# 44     DE  normal      NaN  ...    no   no      no   yes      yes   no  yes
# 45     DE  normal  on-site  ...    no   no      no   yes       no   no   no
# 46  other  normal   hybrid  ...    no   no      no    no       no   no   no
# 47     DE  normal      NaN  ...    no   no      no    no       no   no   no
# 48     SD  normal   hybrid  ...    no   no      no    no       no   no   no
# 49     DE  normal   remote  ...    no   no      no    no       no   no   no
#
#    lightgbm      city   state
# 0        no   Seattle     WA
# 1        no   Seattle      WA
# 2        no   Seattle      WA
# 3        no  Kirkland     WA
# 4        no   Seattle     WA
# 5        no  Kirkland     WA
# 6        no  Kirkland     WA
# 7        no  Bellevue     WA
# 8        no   Seattle      WA
# 9        no   Seattle      WA
# 10       no  Bellevue     WA
# 11       no   Seattle      WA
# 12       no   Seattle     WA
# 13       no   Seattle     WA
# 14       no  Bellevue      WA
# 15       no   Redmond      WA
# 16       no   Seattle      WA
# 17       no   Seattle     WA
# 18       no   Seattle      WA
# 19       no   Seattle     WA
# 20       no   Seattle      WA
# 21       no    remote  remote
# 22       no   Redmond     WA
# 23       no   Redmond     WA
# 24       no   Seattle     WA
# 25       no   Seattle     WA
# 26       no   Seattle     WA
# 27       no   Seattle     WA
# 28       no   Seattle     WA
# 29       no   Seattle      WA
# 30       no   Seattle      WA
# 31       no   Seattle      WA
# 32       no   Seattle     WA
# 33       no   Seattle      WA
# 34       no   Seattle     WA
# 35       no   Redmond      WA
# 36       no    remote  remote
# 37       no   Redmond     WA
# 38       no   Seattle     WA
# 39       no  Bellevue     WA
# 40       no  Bellevue      WA
# 41       no   Seattle     WA
# 42       no   Seattle      WA
# 43       no   Seattle      WA
# 44       no  Bellevue      WA
# 45       no   Seattle     WA
# 46       no   Redmond     WA
# 47       no  Bellevue      WA
# 48       no   Redmond     WA
# 49       no    remote  remote
#
# [50 rows x 92 columns]

# %%
data['state'] = data['state'].apply(lambda x: 'CA' if 'CA' in x or 'California' in x else x)
data['state'] = data['state'].apply(lambda x: 'NY' if 'NY' in x or 'New York' in x else x)
data['state'] = data['state'].apply(lambda x: 'remote' if 'remote' in x or 'United States' in x else x)
data['state'] = data['state'].apply(lambda x: 'WA' if 'WA' in x or 'Washington' in x else x)

data['city'] = data['city'].apply(lambda x: 'New York' if 'New York' in x else x)
data['city'] = data['city'].apply(lambda x: 'San Francisco' if 'San Francisco' in x else x)

# %%
data.to_csv('LI_Data_Jobs.csv', index=False)
